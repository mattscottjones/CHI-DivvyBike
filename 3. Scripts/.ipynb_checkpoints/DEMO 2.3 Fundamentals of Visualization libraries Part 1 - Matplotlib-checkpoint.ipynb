# %% [markdown]
# ## E3 Fundamentals of Visualization libraries Part 1 ß Matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import os

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.2'

# %%
folderpath = r'/Users/matthewjones/Documents/CareerFoundry/Data Visualization with Python/Achievement 2/CHI-DivvyBike/2. Data/Processed Data'

df = pd.read_csv(os.path.join(folderpath, 'chicago_data.csv'), index_col = 0)

# %%
df.columns
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'date', 'avgTemp',
#        '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304        323.0
# 1  17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367        377.0
# 2  17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599      2,904.0
# 3  17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302        747.0
# 4  17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696        183.0
#
#    from_station_id            from_station_name  to_station_id  \
# 0               69       Damen Ave & Pierce Ave            159
# 1              253  Winthrop Ave & Lawrence Ave            325
# 2               98   LaSalle St & Washington St            509
# 3              125         Rush St & Hubbard St            364
# 4              129    Blue Island Ave & 18th St            205
#
#                   to_station_name    usertype gender  birthyear        date  \
# 0       Claremont Ave & Hirsch St  Subscriber   Male     1988.0  2018-01-01
# 1  Clark St & Winnemac Ave (Temp)  Subscriber   Male     1984.0  2018-01-01
# 2             Troy St & North Ave  Subscriber   Male     1989.0  2018-01-01
# 3            Larrabee St & Oak St  Subscriber   Male     1983.0  2018-01-01
# 4            Paulina St & 18th St  Subscriber   Male     1989.0  2018-01-01
#
#    avgTemp
# 0    -18.9
# 1    -18.9
# 2    -18.9
# 3    -18.9
# 4    -18.9

# %%
df.shape
# Out:
# (3603082, 14)

# %%
df.dtypes
# Out:
# trip_id                int64
# start_time            object
# end_time              object
# bikeid                 int64
# tripduration          object
# from_station_id        int64
# from_station_name     object
# to_station_id          int64
# to_station_name       object
# usertype              object
# gender                object
# birthyear            float64
# date                  object
# avgTemp              float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# trip_id                       int64
# start_time                   object
# end_time                     object
# bikeid                        int64
# tripduration                 object
# from_station_id               int64
# from_station_name            object
# to_station_id                 int64
# to_station_name              object
# usertype                     object
# gender                       object
# birthyear                   float64
# date                 datetime64[ns]
# avgTemp                     float64
# dtype: object

# %% [markdown]
# ### Basic plotting with pandas

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#              trip_id           start_time             end_time  bikeid  \
# date
# 2018-01-01  17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 2018-01-01  17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2018-01-01  17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 2018-01-01  17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 2018-01-01  17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
#
#            tripduration  from_station_id            from_station_name  \
# date
# 2018-01-01        323.0               69       Damen Ave & Pierce Ave
# 2018-01-01        377.0              253  Winthrop Ave & Lawrence Ave
# 2018-01-01      2,904.0               98   LaSalle St & Washington St
# 2018-01-01        747.0              125         Rush St & Hubbard St
# 2018-01-01        183.0              129    Blue Island Ave & 18th St
#
#             to_station_id                 to_station_name    usertype gender  \
# date
# 2018-01-01            159       Claremont Ave & Hirsch St  Subscriber   Male
# 2018-01-01            325  Clark St & Winnemac Ave (Temp)  Subscriber   Male
# 2018-01-01            509             Troy St & North Ave  Subscriber   Male
# 2018-01-01            364            Larrabee St & Oak St  Subscriber   Male
# 2018-01-01            205            Paulina St & 18th St  Subscriber   Male
#
#             birthyear  avgTemp
# date
# 2018-01-01     1988.0    -18.9
# 2018-01-01     1984.0    -18.9
# 2018-01-01     1989.0    -18.9
# 2018-01-01     1983.0    -18.9
# 2018-01-01     1989.0    -18.9

# %%
df_temp['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Procedural approach

# %%
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Temperatures daily for 2018')
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.title('Temperatures daily for 2018')
plt.figure(figsize=(10,4))
plt.plot(df_temp['avgTemp'])
plt.show()

# %% [markdown]
# ### Aggregate trips

# %%
df.columns
# Out:
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'date',
#        'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['trip_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  trip_id
# 0 2018-01-01      376
# 1 2018-01-02     1637
# 2 2018-01-03     2493
# 3 2018-01-04     2416
# 4 2018-01-05     2228

# %%
df_group.rename(columns = {'trip_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2018-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2018-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          3603082
# left_only           0
# right_only          0
# Name: count, dtype: int64
# Shape of January 1st is (376, 16)
# Shape of January 2nd is (1637, 16)
# Index(['trip_id', 'start_time', 'end_time', 'bikeid', 'tripduration',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'usertype', 'gender', 'birthyear', 'avgTemp',
#        'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#              trip_id           start_time             end_time  bikeid  \
# date
# 2018-01-01  17536702  2018-01-01 00:12:00  2018-01-01 00:17:23    3304
# 2018-01-01  17536703  2018-01-01 00:41:35  2018-01-01 00:47:52    5367
# 2018-01-01  17536704  2018-01-01 00:44:46  2018-01-01 01:33:10    4599
# 2018-01-01  17536705  2018-01-01 00:53:10  2018-01-01 01:05:37    2302
# 2018-01-01  17536706  2018-01-01 00:53:37  2018-01-01 00:56:40    3696
#
#            tripduration  from_station_id            from_station_name  \
# date
# 2018-01-01        323.0               69       Damen Ave & Pierce Ave
# 2018-01-01        377.0              253  Winthrop Ave & Lawrence Ave
# 2018-01-01      2,904.0               98   LaSalle St & Washington St
# 2018-01-01        747.0              125         Rush St & Hubbard St
# 2018-01-01        183.0              129    Blue Island Ave & 18th St
#
#             to_station_id                 to_station_name    usertype gender  \
# date
# 2018-01-01            159       Claremont Ave & Hirsch St  Subscriber   Male
# 2018-01-01            325  Clark St & Winnemac Ave (Temp)  Subscriber   Male
# 2018-01-01            509             Troy St & North Ave  Subscriber   Male
# 2018-01-01            364            Larrabee St & Oak St  Subscriber   Male
# 2018-01-01            205            Paulina St & 18th St  Subscriber   Male
#
#             birthyear  avgTemp  bike_rides_daily _merge
# date
# 2018-01-01     1988.0    -18.9               376   both
# 2018-01-01     1984.0    -18.9               376   both
# 2018-01-01     1989.0    -18.9               376   both
# 2018-01-01     1983.0    -18.9               376   both
# 2018-01-01     1989.0    -18.9               376   both

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature per trips')
plt.plot(df_temp['avgTemp'])
plt.plot(df_temp['bike_rides_daily'], color = 'red')
plt.show()

# %% [markdown]
# ### OO approach

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")
ax.plot(df_temp['avgTemp'], color = 'blue')

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "blue")

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
plt.show()

# %% [markdown]
# #### Final dual plot

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2018", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures (C)", color = "red",fontsize=14)
plt.title('Temperature and trips in 2018', fontsize = 18)
plt.show()

# %%
plt.style.use('ggplot')

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df_temp['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2018', fontsize = 18)

plt.show()

# %%
# save the plot as a file
destpath = r'/Users/matthewjones/Documents/CareerFoundry/Data Visualization with Python/Achievement 2/CHI-DivvyBike/4. Visualizations'

fig.savefig(os.path.join(destpath, 'trips_temperatures_dual_line.jpg'),
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
